# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import pandas as pd

# 1. Google Sheets API 접근 권한 범위 설정
scope = [
    'https://spreadsheets.google.com/feeds',
    'https://www.googleapis.com/auth/drive',
]

# 2. 서비스 계정 키 파일 경로
json_keyfile = '/Users/jangsunho/Desktop/test/config/f79ee1553412429b4a6e23b6d3acbe9badb87eb9.json'  # 예: './google_bot_service_key.json'

# 3. 인증 처리
credentials = ServiceAccountCredentials.from_json_keyfile_name(json_keyfile, scope)
client = gspread.authorize(credentials)

# 4. 스프레드시트 열기
spreadsheet_key = '1ta-nxCsxo8yzZDeEiUdM0wHK5ok_J61QM5inxLMcrTs'  # 실제 키로 교체
spreadsheet = client.open_by_key(spreadsheet_key)

# 5. 워크시트 선택 (시트 이름 명시 or 첫 번째 시트로 접근)
worksheet = spreadsheet.worksheet('data')  # 첫 번째 시트 사용
# 또는 worksheet = spreadsheet.worksheet('시트이름')

# 6. 시트 데이터 전체 가져오기
data = worksheet.get_all_values()

# 7. pandas DataFrame으로 변환
df = pd.DataFrame(data[1:], columns=data[0])

# %%
df
# Out:
#   cust_num       operation_date          exam_date_x operation motive_x  \
# 0  2198529  2024-12-31 00:00:00  2024-12-31 00:00:00  토릭 렌즈삽입술     소개고객
# 1  2198530  2024-12-31 00:00:00  2024-12-31 00:00:00       스마일       광고
#
#   op_year_week exam_year_week_x total_cost_price            cost_date  \
# 0      2025-01          2025-01          6400000  2024-12-31 00:00:00
# 1      2025-01          2025-01          2400000  2024-12-31 00:00:00
#
#   year_week          exam_date_y            motive_y   birth_day       job  \
# 0   2025-01  2024-12-31 00:00:00  referral_customers  1999-03-25        학생
# 1   2025-01  2024-12-31 00:00:00           search_ad  1989-06-27  자영업/프리랜서
#
#      addr exam_year_week_y
# 0  서울 성북구          2025-01
# 1  서울 서초구          2025-01
